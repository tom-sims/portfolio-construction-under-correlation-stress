# %% [markdown]
# Setup:

# %%
import sys
import os

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %% [markdown]
# Imports:

# %%
from src.risk import (
    max_drawdown,
    sharpe_ratio,
    volatility
)

# %% [markdown]
# Aggregate Results:

# %%
results = pd.DataFrame({
    "Equal Weight": {
        "Sharpe": sharpe_ratio(ew_ret),
        "Max Drawdown": max_drawdown(ew_ret),
        "Volatility": volatility(ew_ret)
    },
    "Mean Variance": {
        "Sharpe": sharpe_ratio(mv_ret),
        "Max Drawdown": max_drawdown(mv_ret),
        "Volatility": volatility(mv_ret)
    },
    "Risk Parity": {
        "Sharpe": sharpe_ratio(rp_ret),
        "Max Drawdown": max_drawdown(rp_ret),
        "Volatility": volatility(rp_ret)
    },
    "Vol Targeted": {
        "Sharpe": sharpe_ratio(vt_ret),
        "Max Drawdown": max_drawdown(vt_ret),
        "Volatility": volatility(vt_ret)
    }
})

results.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 results = pd.DataFrame({
#       2     "Equal Weight": {
# ----> 3         "Sharpe": sharpe_ratio(ew_ret),
#       4         "Max Drawdown": max_drawdown(ew_ret),
#       5         "Volatility": volatility(ew_ret)
#       6     },
#       7     "Mean Variance": {
#       8         "Sharpe": sharpe_ratio(mv_ret),
#       9         "Max Drawdown": max_drawdown(mv_ret),
#      10         "Volatility": volatility(mv_ret)
#      11     },
#      12     "Risk Parity": {
#      13         "Sharpe": sharpe_ratio(rp_ret),
#      14         "Max Drawdown": max_drawdown(rp_ret),
#      15         "Volatility": volatility(rp_ret)
#      16     },
#      17     "Vol Targeted": {
#      18         "Sharpe": sharpe_ratio(vt_ret),
#      19         "Max Drawdown": max_drawdown(vt_ret),
#      20         "Volatility": volatility(vt_ret)
#      21     }
#      22 })
#      24 results.T
#
# NameError: name 'ew_ret' is not defined

# %% [markdown]
# Drawdown Comparison:

# %%
drawdowns = pd.DataFrame({
    "EW": (1 + ew_ret).cumprod(),
    "MV": (1 + mv_ret).cumprod(),
    "RP": (1 + rp_ret).cumprod(),
    "VT": (1 + vt_ret).cumprod()
})

drawdowns.plot(title="Cumulative Performance")
plt.show()
